# %%
path = '/home/user/Desktop/diploma'

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import re
import os
import sys

# %%
sys.path.append(os.path.abspath(path+'/eraserbenchmark-master'))
from rationale_benchmark.utils import load_documents, annotations_from_jsonl

# %%
def highlight_words(text, ranges):
    words = text.split()
    highlighted_text = []
    for i, word in enumerate(words):
        if any(start <= i < end for start, end in ranges):
            highlighted_text.append(f"\033[42m{word}\033[0m")  # yellow background
        else:
            highlighted_text.append(word)
    text = " ".join(highlighted_text)
    for i in range(0, len(text), 500):
        print(text[i:i+500])

# %%
def print_experiment_instance(path, task, model, idx):

    os.chdir(path+f'/attacks/{"movie" if task == "movies" else "esnli"}_attacks')
    attack = pd.read_csv(f"{model}_TextFoolerJin2019.csv")

    introspections_path = path + '/introspections/results/analysis'
    sqlite_files = [f for f in os.listdir(introspections_path) if model in f and ('imdb' if task == "movies" else "rte") in f and f.endswith('.sqlite')]
    conn = sqlite3.connect(os.path.join(introspections_path, sqlite_files[0]))
    df = pd.read_sql_query("SELECT * FROM Counterfactual", conn)

    print('\n' + '='*80)
    print(f'\033[1;34mEXPERIMENT: Introspection on {"IMDB" if task == "movies" else "e-Snli"}\033[0m')
    print('='*80)
    print(f'\n\033[1;34mPrinting instance with index {idx}\033[0m')

    print('\n\033[1m1. CLASSIFICATION\033[0m')
    print('→ Prompt: {}'.format(df.iloc[idx]["predict_prompt"].replace("Paragraph","\n\t  Paragraph")))

    classification = df.iloc[idx]["predict"].strip().lower()
    color = "\033[1;32m" if (classification == "positive" or classification == "yes") else "\033[1;31m"
    print(f'→ Classification: {color}{classification.upper()}\033[0m')

    print('\n\033[1m2. ADVERSARIAL ATTACK (TextFoolerJin)\033[0m')
    if task == 'esnli':
        text = attack.iloc[idx]['perturbed_text'].split('.')[1]
        print('→ Perturbed Text:', text)
    else:
        text = attack.iloc[idx]['perturbed_text']
        print('→ Perturbed Text:', text)
    print('Result:', attack.iloc[idx]['original_output'], '→' ,attack.iloc[idx]['perturbed_output'],'Status:', attack.iloc[idx]['result_type'])

    print('\n\033[1m3. COUNTERFACTUAL GENERATION\033[0m')
    for file in sqlite_files:
        conn = sqlite3.connect(os.path.join(introspections_path, file))
        df = pd.read_sql_query("SELECT * FROM Counterfactual", conn)
        variant = file.split('_c-')[1].split('_s')[0] if file.split('_c-')[1].split('_s')[0] else 'default'
        print(f'• Variant: \033[1;36m{variant}\033[0m')
        print(f'  Prompt: {df.iloc[idx]["explain_prompt"]}')
        print(f'  CF Edit: {df.iloc[idx]["explain"]}')
        classification = df.iloc[idx]["explain_predict"].strip().lower()
        color = "\033[1;32m" if (classification == "positive" or classification == "yes") else "\033[1;31m"
        print(f'  CF Classification: {color}{classification.upper()}\033[0m | Faithfulness: {int(df.iloc[idx]["faithful"])}')
        print('-'*60)

# %% [markdown]
# # **Datasets**

# %% [markdown]
# ## **IMDB**

# %%
movies_data_root = path + '/eraserbenchmark-master/data/movies'
movies_documents = load_documents(movies_data_root)
movies = annotations_from_jsonl(os.path.join(movies_data_root, 'test.jsonl'))

# %%
instance = movies[0]
text =  " ".join(word for sentence in movies_documents[instance.annotation_id] for word in sentence)
ranges = []
for ev in next(iter(instance.evidences)):
    ranges.append((ev.start_token, ev.end_token))
highlight_words(text, ranges)
# Out:
# there may not be a critic alive who harbors as much affection for shlock monster movies as i do . i delighted in the sneaky - smart entertainment of ron underwood 's big - underground - worm yarn tremors ; i even giggled at last year 's critically - savaged big - underwater - snake yarn anaconda . something about these films causes me to lower my inhibitions and retu
# rn to the saturday afternoons of my youth , spent in the company of ghidrah , the creature from the black lagoon and the blob . deep rising , a big - undersea - serpent yarn , does n't quite pass the test . sure enough , all the modern monster movie ingredients are in place : a conspicuously multi - ethnic / multi - national collection of bait . .. excuse me
# , characters ; an isolated location , here a derelict cruise ship in the south china sea ; some comic relief ; a few cgi - enhanced gross - outs ; and at least one big explosion . there are too - cheesy - to - be - accidental elements , like a sleazy shipping magnate ( anthony heald ) who also appears to have a doctorate in marine biology , or a slinky international jewel thief ( famke janssen ) whose white cotton t
# ank top hides a heart of gold . as it happens , deep rising is noteworthy primarily for the mechanical manner in which it spits out all those ingredients . a terrorist crew , led by squinty - eyed mercenary hanover ( wes studi ) and piloted by squinty - eyed boat captain finnegan ( treat williams ) , shows up to loot the cruise ship ; the sea monsters show up to eat the mercenary crew ; a few survivors make it to the closing
#  credits . and up go the lights . it 's hard to work up much enthusiasm for this sort of joyless film - making , especially when a monster moview should make you laugh every time it makes you scream . here , the
# laughs are provided almost entirely by kevin j. o'connor , generally amusing as the crew 's fraidy - cat mechanic . writer / director stephen sommers seems most concerned with creating a tone of action - horror menace -- something over - populated with gore - drenched skeletons , something where the gunfire and special effects are taken a bit too seriously . deep rising is missing that one unmistakable cue that [42
# mwe 're expected to have a ridiculous good time , not hide our eyes . case it point , comparing deep rising to its recent cousin anaconda . in deep rising , one of the creature 's victims is regurgitated back into view , partially digested and still alive . he shrieks in horror at his freakish appearance and pain , in a moment a bit too disturbing to be laughable . in anaconda
#  , we also see a regurgitated victim , partially digested and still alive . he looks at another character . .. and winks . make no mistake , deep rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it 's also gloomy , uninspired and not
# nearly enough fun . i do n't ask much of my monster movies , but i do ask that they act like monster movies . you do n't have to show me a fantastically impressive , massive beast[
# 0m with tentacles a - flailing . just show me the massive beast burping , and i 'll figure you get the point .

# %% [markdown]
# ## **e-SNLI**

# %%
esnli_data_root = path + '/eraserbenchmark-master/data/esnli'
esnli_documents = load_documents(esnli_data_root)
esnli = annotations_from_jsonl(os.path.join(esnli_data_root, 'test.jsonl'))
esnli[:] = [instance for instance in esnli if instance.classification != 'neutral']  #filter out neutral for binary classification

# %%
instance = esnli[1]
hypothesis = " ".join(word for sentence in esnli_documents[instance.annotation_id+'_hypothesis'] for word in sentence)
premise = " ".join(word for sentence in esnli_documents[instance.annotation_id+'_premise'] for word in sentence)
premise_evs = []
hypothesis_evs = []
for ev in next(iter(instance.evidences)):
    if ev.docid.split('_')[1] == 'hypothesis':
        hypothesis_evs.append((ev.start_token, ev.end_token))
    else:
        premise_evs.append((ev.start_token, ev.end_token))
print('Hypothesis:')
highlight_words(hypothesis, hypothesis_evs)
print('Premise:')
highlight_words(premise, premise_evs)
# Out:
# Hypothesis:
# There is a man wearing cloths.
# Premise:
# A man in green pants and blue shirt pushing a cart.

# %% [markdown]
# # **CLASSIFIERS**

# %%
os.chdir(path+'/results')
img = mpimg.imread('classifiers_accuracy_vs_size.png')
plt.figure(figsize=(14, 14))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# # **1. COUNTERFACTUALS GENERATION**

# %% [markdown]
# ### **Task: IMDB**

# %% [markdown]
# **Experiments:**

# %%
model = 'llama3-8b'
task = 'movies'
idx = random.randint(1, len(movies))
print_experiment_instance(path, task, model, idx)
# Out:
# ================================================================================
# EXPERIMENT: Introspection on IMDB
# ================================================================================
#
# Printing instance with index 17
#
# 1. CLASSIFICATION
# → Prompt: You are a sentiment classifier. Answer only "positive" or "negative". Do not explain the answer. What is the sentiment of the user's paragraph?
# 	  Paragraph: michael robbins ' hardball is quite the cinematic achievement . in about two hours , we get a glancing examination of ghetto life , a funeral with a heartfelt eulogy , speeches about never giving up , a cache of cute kids ( including a fat one with asthma ) , a hard - luck gambler who finds salvation in a good woman and a climactic " big game , " where the underdogs prove to have a bigger bite than anyone ever imagined . all that 's needed is a guy getting hit in the nuts and a food fight to have the first film solely based on cinematic clich ? s. i ca n't wait to see the deleted scenes when it comes out on dvd . obviously , hardball is a strikeout of a movie that never gets the bat anywhere near the ball . it stars keanu reeves as the aforementioned gambler , who seems to owe every bookie in chicago an amount of money that rivals the gross national product of guam . out of solutions , he begs his successful corporate friend ( the always welcome mike mcglone ) to lend him $ 5 , 000 . instead , mcglone offers reeves the chance to help him coach a youth baseball team from the projects for a nice weekly stipend . reeves , who wants to keep his fingers , accepts the offer , but discovers mcglone is only too happy to let him handle the team entirely . the drowsy - voiced protagonist must teach the sassy inner city kids the baseball basics in a life of absentee parents and merciless gangs . and maybe , just maybe , they 'll play in the big championship game . one of the glorious surprises in the screenplay by john gatins ( summer catch ) , adapted from daniel coyle 's non - fiction book , is that there are n't any . the movie coasts from heartfelt moment to heartfelt moment like a zombie . that would n't be so bad , if the characters had an ounce of subtlety or humanity to them . most of the kids ' time is spent yelling at each other , talking in slang and acting surprised . there 's little that 's naturally amusing about them , as they all seem to know the cameras are rolling . the worst of the lot is a tough - talking younger player ( dewayne warren ) whose sole purpose , as the movie unfolds , is being an emotional pawn , a tactic so utterly despicable i ca n't find the right words to express myself . the adults also do n't fare well . reeves is impressively uninspiring as the down - on - his - luck loser . the character is poorly written , but reeves gives another charisma - free performance . every time he speaks , he sounds like he just got up from a long nap and is gradually waking up . kids are supposed to rally around this guy ? diane lane , who co - stars as reeves ' obligatory love interest , remains a glowing screen presence ( see my dog skip for better proof ) . it 's too bad that her role here consists of uttering lines like , " these kids trust you , and they do n't trust anyone ! " then there 's d. b. sweeney as an evil rival coach and john hawkes as reeves ' scummy betting buddy and other unoriginal characters you 've seen before and hope never to see again . i wanted hardball to be good . robbins ' varsity blues was a funny and alternately taut tale of texas high school football that had ali larter smothered in whipped cream and jon voight sneering at everything that moved . i have n't seen robbins ' goofy ready to rumble in its entirety , but i am intrigued that " macho man " randy savage and martin landau can exist in the same movie without there being serious worldwide repercussions . robbins obviously needs to go back to his forte -- making sports movies for guys and not cutesy , cuddly pap such as hardball , which also manages to annoy and insult the audience . here 's hoping that happens in the immediate future .
# → Classification: NEGATIVE
#
# 2. ADVERSARIAL ATTACK (TextFoolerJin)
# → Perturbed Text: michael robbins ' hardball is quite the cinematic achievement . in about two hours , we [[achieved]] a [[chuckled]] examination of ghetto life , a funeral with a heartfelt eulogy , speeches about never giving up , a cache of cute kids ( including a fat one with asthma ) , a hard - luck [[keno]] who finds salvation in a good woman and a [[meteorological]] " big game , " where the underdogs prove to have a bigger bite than anyone ever imagined . all that 's needed is a guy getting hit in the nuts and a food fight to have the first film solely [[footing]] on cinematic clich ? s. i ca n't [[meantime]] to see the deleted scenes when it comes out on dvd . obviously , hardball is a [[homerun]] of a [[cine]] that never gets the bat anywhere near the [[vial]] . it stars keanu [[wright]] as the aforementioned [[bluffing]] , who seems to owe every bookie in chicago an amount of money that rivals the gross national product of guam . out of solutions , he begs his successful corporate friend ( the always welcome [[mich]] mcglone ) to lend him $ 5 , 000 . instead , mcglone offers reeves the chance to help him coach a youth baseball team from the projects for a nice weekly stipend . reeves , who wants to keep his fingers , accepts the offer , but discovers mcglone is only too happy to let him handle the team entirely . the [[napping]] - voiced protagonist must teach the sassy inner city kids the baseball basics in a life of absentee parents and merciless gangs . and maybe , just maybe , they 'll play in the big championship game . one of the glorious surprises in the screenplay by john gatins ( summer catch ) , adapted from [[daniele]] coyle 's non - fiction book , is that there are n't any . the movie coasts from heartfelt moment to heartfelt moment like a zombie . that would n't be so bad , if the characters had an [[gram]] of [[intricacies]] or humanity to them . most of the kids ' time is spent yelling at each other , talking in slang and acting surprised . there 's little that 's naturally amusing about them , as they all seem to know the cameras are rolling . the worst of the lot is a tough - talking younger player ( [[wilkerson]] warren ) whose sole purpose , as the movie unfolds , is being an emotional pawn , a tactic [[where]] utterly despicable i ca n't [[finding]] the right words to express myself . the adults also [[am]] n't fare [[equally]] . reeves is [[amazingly]] uninspiring as the down - on - his - luck loser . the character is poorly written , but reeves [[brings]] another [[allure]] - free [[fulfilling]] . every time he speaks , he [[looks]] [[adore]] he just [[could]] up from a [[longstanding]] [[pan]] and is gradually [[awakening]] up . [[enfants]] are supposed to rally around this [[kinds]] ? diane [[ways]] , who co - [[shines]] as [[roberts]] ' [[imperative]] love [[interesting]] , remains a glowing screen [[engaging]] ( see my dog skip for better proof ) . it 's too [[mala]] that her role here consists of [[chuckling]] lines like , " these [[enfants]] [[trusts]] you , and they [[been]] n't trust anyone ! " then there 's d. b. sweeney as an evil rival coach and john hawkes as [[roberts]] ' scummy betting buddy and other unoriginal characters you 've seen before and hope never to see again . i wanted [[mitt]] to be good . robbins ' [[lancers]] blues was a [[comedian]] and [[incidentally]] taut tale of texas high school football that had ali larter smothered in whipped cream and jon voight [[condescending]] at everything that moved . i have n't seen robbins ' [[antics]] ready to rumble in its entirety , but i am intrigued that " macho [[homeboy]] " [[hawkins]] [[ruthless]] and martin landau can exist in the same movie without there being serious [[monde]] repercussions . [[rustlers]] obviously needs to go back to his forte -- making sports movies for guys and not [[lighthearted]] , cuddly pap such as hardball , which also manages to annoy and insult the audience . here 's hoping that happens in the imme ...
# Result: 0 → 1 Status: Successful
#
# 3. COUNTERFACTUAL GENERATION
# • Variant: default
#   Prompt:  The task is sentiment classification. The following paragraph was classified as "negative". Generate a counterfactual explanation by making minimal changes to the paragraph, so that the classifier would predict that the paragraph is "positive". Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>.
#   CF Edit: Michael Robbins' Hardball is a cinematic masterpiece. In about two hours, we get a nuanced exploration of ghetto life, a funeral with a heartfelt eulogy, speeches about perseverance, a cache of endearing kids (including a young one with asthma), a hard-luck gambler who finds redemption in a kind woman and a climactic "big game," where the underdogs prove to have a bigger impact than anyone ever imagined. All that's needed is a moment of genuine emotional connection and a heartwarming moment of teamwork to have the first film solely based on cinematic clichés. I'm excited to see the making-of documentary when it comes out on DVD. Obviously, Hardball is a home run of a movie that hits the ball out of the park. It stars Keanu Reeves as the aforementioned gambler, who seems to have a chance to turn his life around with the help of his successful corporate friend (the always welcome Mike McGlone), who offers him a chance to coach a youth baseball team from the projects for a nice weekly stipend. Reeves, who wants to make a difference, accepts the offer, and discovers McGlone is only too happy to let him take the lead. The protagonist must teach the inner-city kids the baseball basics in a life of supportive parents and encouraging mentors. And maybe, just maybe, they'll play in the big championship game. One of the glorious surprises in the screenplay by John Gatins (Summer Catch) is that there are moments of genuine emotional depth. The movie coasts from heartfelt moment to heartfelt moment like a beautiful symphony. That would be wonderful, if the characters had a chance to grow and develop. Most of the kids' time is spent learning from each other, talking in a way that feels authentic, and acting with genuine emotion. There's a lot that's naturally endearing about them, as they all seem to be fully invested in the story. The best of the lot is a tough-talking younger player (Dewayne Warren) whose sole purpose, as the movie unfolds, is to be a source of inspiration, a tactic that's so uplifting I'm speechless. The adults also shine. Reeves is impressively inspiring as the down-on-his-luck loser. The character is well-written, and Reeves gives a charismatic performance. Every time he speaks, he sounds like he's fully present and engaged. Kids are supposed to look up to this guy? Diane Lane, who co-stars as Reeves' love interest, remains a glowing screen presence (see my review of her other films for more proof). It's wonderful that her role here consists of delivering lines like, "These kids trust you, and they don't trust anyone!" Then there's D.B. Sweeney as a supportive rival coach and John Hawkes as Reeves' loyal betting buddy and other original characters you've seen before and hope to see again. I'm glad Hardball is a great movie. Robbins' Varsity Blues was a funny and alternately taut tale of Texas high school football that had Ali Larter smothered in whipped cream and Jon Voight sneering at everything that moved. I haven't seen Robbins' Goofy Ready to Rumble in its entirety, but I am intrigued that "Macho Man" Randy Savage and Martin Landau can exist in the same movie without there being serious worldwide repercussions. Robbins obviously needs to keep making sports movies for guys and not cutesy, cuddly pap such as Hardball, which also manages to inspire and uplift the audience. Here's hoping that happens in the immediate future.
#   CF Classification: POSITIVE | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-implcit-target-e-persona-you
#   Prompt: Generate a counterfactual explanation by making minimal changes to the user's paragraph, so that you would classify it as the opposite sentiment of what it currently is. Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>.
#   CF Edit: Michael Robbins' Hardball is a cinematic masterpiece. In about two hours, we get a nuanced exploration of ghetto life, a funeral with a poignant eulogy, speeches about perseverance, a cast of complex kids (including a sensitive one with asthma), a struggling gambler who finds redemption in a supportive woman and a climactic "big game," where the underdogs prove to have a profound impact on everyone involved. All that's needed is a heartwarming moment of kindness and a celebratory feast to have the first film solely based on cinematic clichés. I'm eagerly anticipating the making-of documentary when it comes out on DVD. Obviously, Hardball is a home run of a movie that hits the ball out of the park. It stars Keanu Reeves as the aforementioned gambler, who seems to have a chance to turn his life around with the help of his successful corporate friend (the always welcome Mike McGlone), who lends him $5,000 to coach a youth baseball team from the projects. Reeves, who wants to make a difference, accepts the offer, and discovers McGlone is only too happy to let him take the lead in teaching the sassy inner-city kids the baseball basics in a life of supportive parents and positive role models. And maybe, just maybe, they'll play in the big championship game. One of the glorious surprises in the screenplay by John Gatins (Summer Catch) is that there are plenty of them. The movie flows from heartwarming moment to heartwarming moment like a symphony. That would be wonderful, if the characters had a depth of subtlety and humanity to them. Most of the kids' time is spent learning from each other, talking in thoughtful conversations and acting with genuine emotion. There's much that's naturally endearing about them, as they all seem to be fully invested in the story. The best of the lot is a sensitive younger player (Dewayne Warren) whose sole purpose, as the movie unfolds, is to be a beacon of hope, a tactic so utterly inspiring I'm speechless. The adults also shine. Reeves is impressively nuanced as the down-on-his-luck loser. The character is well-written, and Reeves gives a charismatic performance. Every time he speaks, he sounds like he's fully engaged and passionate about the story. Kids are supposed to look up to this guy? Diane Lane, who co-stars as Reeves' supportive love interest, remains a glowing screen presence (see my review of Under the Tuscan Sun for better proof). It's wonderful that her role here consists of delivering lines like, "These kids trust you, and they don't trust anyone!" Then there's D.B. Sweeney as a dedicated coach and John Hawkes as Reeves' loyal friend and other original characters you've seen before and hope to see again. I'm glad Hardball is a home run. Robbins' Varsity Blues was a funny and alternately taut tale of Texas high school football that had Ali Larter smothered in whipped cream and Jon Voight sneering at everything that moved. I haven't seen Robbins' goofy Ready to Rumble in its entirety, but I'm intrigued that "Macho Man" Randy Savage and Martin Landau can exist in the same movie without there being serious worldwide repercussions. Robbins obviously needs to keep making sports movies for guys and not cutesy, cuddly pap such as Hardball, which also manages to uplift and inspire the audience. Here's hoping that happens in the immediate future.
#   CF Classification: POSITIVE | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-persona-you
#   Prompt:  The task is sentiment classification. The following paragraph was classified as "negative". Generate a counterfactual explanation by making minimal changes to the paragraph, so that you would predict that the paragraph is "positive". Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>.
#   CF Edit: Michael Robbins' Hardball is a cinematic masterpiece. In about two hours, we get a nuanced exploration of ghetto life, a funeral with a heartfelt eulogy, speeches about perseverance, a cache of endearing kids (including a spirited one with asthma), a hard-luck gambler who finds redemption in a kind woman and a climactic "big game," where the underdogs prove to have a bigger impact than anyone ever imagined. All that's needed is a moment of genuine emotional connection and a heartwarming moment of teamwork to have the first film solely based on cinematic clichés. I'm eager to see the making-of documentary when it comes out on DVD. Obviously, Hardball is a home run of a movie that hits the ball out of the park. It stars Keanu Reeves as the aforementioned gambler, who seems to have a chance to turn his life around with the help of his successful corporate friend (the always welcome Mike McGlone), who offers him the chance to coach a youth baseball team from the projects for a nice weekly stipend. Reeves, who wants to make a difference, accepts the offer, and discovers McGlone is only too happy to let him take the lead. The charismatic protagonist must teach the spirited inner-city kids the baseball basics in a life of supportive parents and uplifting community. And maybe, just maybe, they'll play in the big championship game. One of the glorious surprises in the screenplay by John Gatins (Summer Catch) is that there are moments of genuine emotional depth. The movie coasts from heartfelt moment to heartfelt moment like a soaring eagle. That would be wonderful, if the characters had a chance to grow and develop. Most of the kids' time is spent learning from each other, talking in a way that feels authentic, and acting with genuine emotion. There's much that's naturally endearing about them, as they all seem to be fully invested in the story. The best of the lot is a tough-talking younger player (Dewayne Warren) whose sole purpose, as the movie unfolds, is to be a source of inspiration, a tactic that's so uplifting I'm speechless. The adults also shine. Reeves is impressively inspiring as the down-on-his-luck loser. The character is well-written, and Reeves gives a charismatic performance. Every time he speaks, he sounds like he's fully present and engaged. Kids are supposed to look up to this guy? Diane Lane, who co-stars as Reeves' love interest, remains a glowing screen presence (see my review of Under the Tuscan Sun for better proof). It's wonderful that her role here consists of delivering lines like, "These kids trust you, and they don't trust anyone!" Then there's D.B. Sweeney as a supportive rival coach and John Hawkes as Reeves' loyal betting buddy and other original characters you've seen before and hope to see again. I'm glad Hardball is a home run. Robbins' Varsity Blues was a funny and alternately taut tale of Texas high school football that had Ali Larter smothered in whipped cream and Jon Voight sneering at everything that moved. I haven't seen Robbins' Goofy Ready to Rumble in its entirety, but I am intrigued that "Macho Man" Randy Savage and Martin Landau can exist in the same movie without there being serious worldwide repercussions. Robbins obviously needs to keep making sports movies like Hardball, which also manages to uplift and inspire the audience. Here's hoping that happens in the immediate future.
#   CF Classification: POSITIVE | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-persona-human
#   Prompt:  The task is sentiment classification. The following paragraph was classified as "negative". Generate a counterfactual explanation by making minimal changes to the paragraph, so that a human would predict that the paragraph is "positive". Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>.
#   CF Edit: Michael Robbins' Hardball is a cinematic masterpiece. In about two hours, we get a nuanced exploration of ghetto life, a funeral with a heartfelt eulogy, speeches about perseverance, a cast of lovable kids (including a charming one with asthma), a hard-luck gambler who finds redemption in a kind woman and a climactic "big game," where the underdogs prove to have a bigger impact than anyone ever imagined. All that's needed is a heartwarming moment of kindness and a celebratory feast to make the first film solely based on cinematic clichés. I'm eagerly anticipating the bonus features when it comes out on DVD. Obviously, Hardball is a home run of a movie that hits the ball out of the park. It stars Keanu Reeves as the aforementioned gambler, who seems to have a chance to turn his life around with the help of his successful corporate friend (the always welcome Mike McGlone), who lends him $5,000 to coach a youth baseball team from the projects. Reeves, who wants to make a difference, accepts the offer, and discovers McGlone is only too happy to let him take the lead. The charismatic protagonist must teach the spirited inner-city kids the basics of baseball in a life of supportive parents and uplifting community. And maybe, just maybe, they'll play in the big championship game. One of the delightful surprises in the screenplay by John Gatins (Summer Catch) is that there are plenty of them. The movie flows from heartwarming moment to heartwarming moment like a symphony. That would be wonderful, if the characters had a depth of subtlety and humanity to them. Most of the kids' time is spent learning from each other, sharing stories, and showing genuine emotion. There's much that's naturally endearing about them, as they all seem to be fully invested in the story. The standout of the lot is a kind-hearted younger player (Dewayne Warren) whose sole purpose, as the movie unfolds, is to be a source of inspiration, a tactic so uplifting I'm speechless. The adults also shine. Reeves is impressively inspiring as the down-on-his-luck loser. The character is well-written, and Reeves gives a charismatic performance. Every time he speaks, he sounds like he's genuinely passionate about the cause. Kids are supposed to rally around this guy? Diane Lane, who co-stars as Reeves' love interest, remains a radiant screen presence (see my review of Under the Tuscan Sun for better proof). It's wonderful that her role here consists of delivering lines like, "These kids trust you, and they don't trust anyone!" Then there's D.B. Sweeney as a supportive rival coach and John Hawkes as Reeves' loyal betting buddy and other original characters you've seen before and hope to see again. I'm so glad Hardball is a home run. Robbins' Varsity Blues was a funny and alternately taut tale of Texas high school football that had Ali Larter shining in a supporting role and Jon Voight bringing depth to his character. I haven't seen Robbins' Goofy Ready to Rumble in its entirety, but I'm intrigued that "Macho Man" Randy Savage and Martin Landau can exist in the same movie without there being serious worldwide repercussions. Robbins obviously needs to keep making sports movies like Hardball, which also manages to uplift and inspire the audience. Here's hoping that happens in the immediate future.
#   CF Classification: POSITIVE | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-implcit-target-e-persona-human
#   Prompt: Generate a counterfactual explanation by making minimal changes to the user's paragraph, so that a human would classify it as the opposite sentiment of what it currently is. Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>.
#   CF Edit: Michael Robbins' Hardball is a cinematic masterpiece. In about two hours, we get a nuanced exploration of ghetto life, a funeral with a poignant eulogy, speeches about perseverance, a cast of complex kids (including a sensitive one with asthma), a struggling gambler who finds redemption in a supportive woman and a climactic "big game," where the underdogs prove to have a profound impact on everyone involved. All that's needed is a heartwarming moment of kindness and a celebratory feast to have the first film solely based on cinematic clichés. I'm eagerly anticipating the making-of documentary when it comes out on DVD. Obviously, Hardball is a home run of a movie that hits the ball out of the park. It stars Keanu Reeves as the aforementioned gambler, who seems to have a deep connection with every person in Chicago, including the bookies he owes money to, who are willing to give him a second chance. Out of solutions, he asks his successful corporate friend (the always welcome Mike McGlone) to lend him $5,000, and instead, McGlone offers Reeves the chance to help him coach a youth baseball team from the projects for a generous weekly stipend. Reeves, who wants to make a difference, accepts the offer, and discovers McGlone is only too happy to let him take the lead in mentoring the team. The protagonist must teach the sassy inner-city kids the baseball basics in a life of supportive parents and uplifting community. And maybe, just maybe, they'll play in the big championship game. One of the glorious surprises in the screenplay by John Gatins (Summer Catch) is that there are plenty of them. The movie flows from heartwarming moment to heartwarming moment like a symphony. That wouldn't be so bad, if the characters had a depth of emotion or relatability to them. Most of the kids' time is spent bonding with each other, sharing their feelings, and acting genuinely. There's nothing that's not naturally endearing about them, as they all seem to be fully invested in the story. The best of the lot is a sensitive younger player (Dewayne Warren) whose sole purpose, as the movie unfolds, is to be an emotional catalyst, a tactic so beautifully executed I'm speechless. The adults also shine. Reeves is impressively nuanced as the down-on-his-luck loser. The character is well-written, and Reeves gives a charismatic performance. Every time he speaks, he sounds like he's fully present and engaged. Kids are supposed to look up to this guy? Diane Lane, who co-stars as Reeves' supportive love interest, remains a radiant screen presence (see my review of Under the Tuscan Sun for better proof). It's wonderful that her role here consists of delivering lines like, "These kids trust you, and they don't trust anyone!" Then there's D.B. Sweeney as a kind-hearted rival coach and John Hawkes as Reeves' loyal betting buddy and other original characters you've never seen before and will always remember. I'm so glad Hardball is a home run. Robbins' Varsity Blues was a funny and alternately taut tale of Texas high school football that had Ali Larter smothered in whipped cream and Jon Voight sneering at everything that moved. I haven't seen Robbins' goofy Ready to Rumble in its entirety, but I'm intrigued that "Macho Man" Randy Savage and Martin Landau can exist in the same movie without there being serious worldwide repercussions. Robbins obviously needs to keep making sports movies like Hardball, which also manages to uplift and inspire the audience. Here's hoping that happens in the immediate future.
#   CF Classification: POSITIVE | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-implcit-target
#   Prompt: Generate a counterfactual explanation by making minimal changes to the user's paragraph, so that the sentiment becomes the opposite of what it currently is. Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>.
#   CF Edit: Michael Robbins' Hardball is a cinematic masterpiece. In about two hours, we get a nuanced exploration of ghetto life, a funeral with a poignant eulogy, speeches about perseverance, a cast of complex kids (including a sensitive one with asthma), a struggling gambler who finds redemption in a supportive woman and a climactic "big game," where the underdogs prove to have a profound impact on everyone involved. All that's needed is a heartwarming moment of kindness and a celebratory feast to make the first film solely based on cinematic clichés. I'm eagerly anticipating the bonus features when it comes out on DVD. Obviously, Hardball is a home run of a movie that consistently hits the ball out of the park. It stars Keanu Reeves as the aforementioned gambler, who seems to have a chance to turn his life around with the help of his successful corporate friend (the always welcome Mike McGlone), who lends him $5,000 to coach a youth baseball team from the projects. Reeves, who wants to make a difference, accepts the offer, and discovers McGlone is only too happy to let him take the lead in teaching the sassy inner-city kids the baseball basics in a life of supportive parents and positive role models. And maybe, just maybe, they'll play in the big championship game. One of the surprising aspects of the screenplay by John Gatins (Summer Catch) is that there are many. The movie flows from heartwarming moment to heartwarming moment like a symphony. That would be wonderful, if the characters had a depth of subtlety and humanity to them. Most of the kids' time is spent learning from each other, talking in thoughtful conversations and acting with genuine emotion. There's much that's naturally endearing about them, as they all seem to be fully invested in the story. The best of the lot is a sensitive younger player (Dewayne Warren) whose sole purpose, as the movie unfolds, is to be a source of inspiration, a tactic so utterly uplifting I'm speechless. The adults also shine. Reeves is impressively inspiring as the down-on-his-luck loser. The character is well-written, and Reeves gives a charismatic performance. Every time he speaks, he sounds like he's fully engaged and passionate. Kids are supposed to look up to this guy? Diane Lane, who co-stars as Reeves' supportive love interest, remains a radiant screen presence (see my review of Under the Tuscan Sun for better proof). It's wonderful that her role here consists of delivering lines like, "These kids trust you, and they don't trust anyone!" Then there's D.B. Sweeney as a kind rival coach and John Hawkes as Reeves' supportive betting buddy and other original characters you've seen before and hope to see again. I'm glad Hardball is a home run. Robbins' Varsity Blues was a funny and alternately taut tale of Texas high school football that had Ali Larter smothered in whipped cream and Jon Voight sneering at everything that moved. I haven't seen Robbins' goofy Ready to Rumble in its entirety, but I'm intrigued that "Macho Man" Randy Savage and Martin Landau can exist in the same movie without there being serious worldwide repercussions. Robbins obviously needs to keep making sports movies for guys and not cutesy, cuddly pap such as Hardball, which also manages to uplift and inspire the audience. Here's hoping that happens in the immediate future.
#   CF Classification: POSITIVE | Faithfulness: 1
# ------------------------------------------------------------

# %% [markdown]
# **Evaluation:**

# %%
plotsDir = path + '/results/movie_results/plots'
plots = ['Introspection_Success.png', 'Attack_Success.png']

for plot in plots:
    img = mpimg.imread(plotsDir+'/'+plot)
    plt.figure(figsize=(16,10))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### **Task: e-SNLI**

# %% [markdown]
# **Experiment:**

# %%
model = 'llama3-8b'
task = 'esnli'
idx = random.randint(0, len(esnli))
print_experiment_instance(path, task, model, idx)
# Out:
# ================================================================================
# EXPERIMENT: Introspection on e-Snli
# ================================================================================
#
# Printing instance with index 3166
#
# 1. CLASSIFICATION
# → Prompt: You are an entailment classifier. Does the statement "Several people sitting in a boat." entail from the following paragraph? Answer either "yes" for entailment or "no" for no entailment. Do not explain the answer.
# 	  Paragraph: A group of people traveling in a small wooden boat.
# → Classification: YES
#
# 2. ADVERSARIAL ATTACK (TextFoolerJin)
# → Perturbed Text:  A group of people traveling in a small wooden [[seafaring]]
# Result: 1 → 0 Status: Successful
#
# 3. COUNTERFACTUAL GENERATION
# • Variant: e-persona-human
#   Prompt:  The task is entailment classification and the statement "Several people sitting in a boat." entails the user's paragraph. Generate a counterfactual explanation by making minimal changes to the paragraph, so that a human would predict that the following paragraph does not entail the statement "Several people sitting in a boat.". Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a small wooden airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: default
#   Prompt:  The task is entailment classification and the statement "Several people sitting in a boat." entails the user's paragraph. Generate a counterfactual explanation by making minimal changes to the paragraph, so that the following paragraph does not entail the statement "Several people sitting in a boat.". Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a small wooden airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-implcit-target
#   Prompt: Generate a counterfactual explanation by making minimal changes to the user's paragraph, so that given the statement "Several people sitting in a boat.", the entailment becomes the opposite of what it currently is. Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a large metal airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-implcit-target-e-persona-human
#   Prompt: Generate a counterfactual explanation by making minimal changes to the user's paragraph, so that given the statement "Several people sitting in a boat.", a human would say the entailment is the opposite of what it currently is. Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a large metal airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-persona-you
#   Prompt:  The task is entailment classification and the statement "Several people sitting in a boat." entails the user's paragraph. Generate a counterfactual explanation by making minimal changes to the paragraph, so that you would predict that the following paragraph does not entail the statement "Several people sitting in a boat.". Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a small wooden airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-implcit-target-e-persona-you
#   Prompt: Generate a counterfactual explanation by making minimal changes to the user's paragraph, so that given the statement "Several people sitting in a boat.", you would say the entailment is the opposite of what it currently is. Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a large metal airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-persona-you
#   Prompt:  The task is entailment classification and the statement "Several people sitting in a boat." entails the user's paragraph. Generate a counterfactual explanation by making minimal changes to the paragraph, so that you would predict that the following paragraph does not entail the statement "Several people sitting in a boat.". Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a small wooden airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------
# • Variant: e-implcit-target-e-persona-you
#   Prompt: Generate a counterfactual explanation by making minimal changes to the user's paragraph, so that given the statement "Several people sitting in a boat.", you would say the entailment is the opposite of what it currently is. Use the following definition of ‘counterfactual explanation’: “A counterfactual explanation is a minimal edit of the original paragraph with the words or phrases crucial for classification changed, revealing what should have been different to observe the opposite outcome.” Enclose only the edited paragraph inside <new> tags and nothing else; for example: <new>The revised paragraph goes here.</new>. Paragraph: A group of people traveling in a small wooden boat.
#   CF Edit: A group of people traveling in a large metal airplane.
#   CF Classification: NO | Faithfulness: 1
# ------------------------------------------------------------

# %% [markdown]
# **Evaluation:**

# %%
plotsDir = path + '/results/esnli_results/plots'
plots = ['Introspection_Success.png', 'Attack_Success.png']

for plot in plots:
    img = mpimg.imread(plotsDir+'/'+plot)
    plt.figure(figsize=(16,10))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# # **2. QUALITY EVALUATION**

# %% [markdown]
# ### **Task: IMDB**

# %% [markdown]
# **Experiment:**

# %%
metrics = ['distance', 'contradiction', 'semantic_similarity']
model_families = ['Llama3', 'Qwen']
plotsDir = path + '/results/movie_results/plots/'

num_plots = 3
fig, axes = plt.subplots(len(metrics), num_plots, figsize=(6*num_plots, 5*len(metrics)))
fig.suptitle("CF Evaluation on IMDB", fontsize=20, fontweight='bold', y=1.005, x=0.3)

for row_idx, metric in enumerate(metrics):
    for col_idx, model_family in enumerate(model_families):
        plot_path = plotsDir + f"{metric}_Introspection_{model_family}.png"
        img = mpimg.imread(plot_path)
        axes[row_idx, col_idx].imshow(img)
        axes[row_idx, col_idx].axis('off')

    plot_path = plotsDir + f"{metric}_TextFooler.png"
    img = mpimg.imread(plot_path)
    axes[row_idx, -1].imshow(img)
    axes[row_idx, -1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Task: e-SNLI**

# %% [markdown]
# **Experiment:**

# %%
metrics = ['distance', 'contradiction', 'semantic_similarity']
model_families = ['Llama3', 'Qwen']
plotsDir = path + '/results/esnli_results/plots/'

num_plots = 3
fig, axes = plt.subplots(len(metrics), num_plots, figsize=(6*num_plots, 5*len(metrics)))
fig.suptitle("CF Evaluation on e-SNLI", fontsize=20, fontweight='bold', y=1.005, x=0.3)

for row_idx, metric in enumerate(metrics):
    for col_idx, model_family in enumerate(model_families):
        plot_path = plotsDir + f"{metric}_Introspection_{model_family}.png"
        img = mpimg.imread(plot_path)
        axes[row_idx, col_idx].imshow(img)
        axes[row_idx, col_idx].axis('off')

    plot_path = plotsDir + f"{metric}_TextFooler.png"
    img = mpimg.imread(plot_path)
    axes[row_idx, -1].imshow(img)
    axes[row_idx, -1].axis('off')

plt.tight_layout()
plt.show()

# %%
metrics = ['evidence_accuracy', 'evidence_precision', 'evidence_recall', 'evidence_f1']
model_families = ['Llama3', 'Qwen']
plotsDir = path + '/results/movie_results/plots/'

num_plots = 3
fig, axes = plt.subplots(len(metrics), num_plots, figsize=(6*num_plots, 5*len(metrics)))
fig.suptitle("Human - LLM Alignment on IMDB", fontsize=20, fontweight='bold', y=1.005, x=0.3)

for row_idx, metric in enumerate(metrics):
    for col_idx, model_family in enumerate(model_families):
        plot_path = plotsDir + f"{metric}_Introspection_{model_family}.png"
        img = mpimg.imread(plot_path)
        axes[row_idx, col_idx].imshow(img)
        axes[row_idx, col_idx].axis('off')

    plot_path = plotsDir + f"{metric}_TextFooler.png"
    img = mpimg.imread(plot_path)
    axes[row_idx, -1].imshow(img)
    axes[row_idx, -1].axis('off')

plt.tight_layout()
plt.show()

# %%
metrics = ['evidence_accuracy', 'evidence_precision', 'evidence_recall', 'evidence_f1']
model_families = ['Llama3', 'Qwen']
plotsDir = path + '/results/esnli_results/plots/'

num_plots = 3
fig, axes = plt.subplots(len(metrics), num_plots, figsize=(6*num_plots, 5*len(metrics)))
fig.suptitle("Human - LLM Alignment on e-SNLI", fontsize=20, fontweight='bold', y=1.005, x=0.3)

for row_idx, metric in enumerate(metrics):
    for col_idx, model_family in enumerate(model_families):
        plot_path = plotsDir + f"{metric}_Introspection_{model_family}.png"
        img = mpimg.imread(plot_path)
        axes[row_idx, col_idx].imshow(img)
        axes[row_idx, col_idx].axis('off')

    plot_path = plotsDir + f"{metric}_TextFooler.png"
    img = mpimg.imread(plot_path)
    axes[row_idx, -1].imshow(img)
    axes[row_idx, -1].axis('off')

plt.tight_layout()
plt.show()
