# %%
import sys
import sqlite3
import pandas as pd
import re
import torch
import glob
import numpy as np
import json
from google.colab import drive
drive.mount('/content/drive')
import os
path = '/content/drive/MyDrive/thesis/code'
os.chdir(path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # metrics

# %%
import sys
sys.path.append(os.path.abspath(path+'/results'))
from utils import evaluate_cf, plot_attack_comparison, plot_size_comparison

# %% [markdown]
# # load data

# %%
os.chdir(path + '/eraserbenchmark-master')
from rationale_benchmark.utils import load_documents, load_datasets, annotations_from_jsonl, Annotation
data_root = os.path.join('data', 'movies')
movies_docs = load_documents(data_root)
movies = annotations_from_jsonl(os.path.join(data_root, 'test.jsonl'))

# %%
def collect_df(model_name, path, movies, movies_docs):
    """
    Collect results for all prompt-engineering variants (including combined ones)
    and store each variant as its own column.
    """
    base_dir = os.path.join(path, f"introspections/movies_introspections/{model_name}/results/analysis")
    os.chdir(base_dir)

    # Find all .sqlite result files
    sqlite_files = glob.glob("analysis_m-*_p-test_t-counterfactual_*.sqlite")

    # Initialize main DataFrame with test-level info
    resDf = pd.DataFrame({
        'texts': [' '.join([' '.join(sentence) for sentence in movies_docs[instance.annotation_id]]) for instance in movies],
        'evidences': [[ev.text for ev in next(iter(instance.evidences))] for instance in movies],
        'evidence_ranges': [[(ev.start_token, ev.end_token) for ev in next(iter(instance.evidences))] for instance in movies]
    })

    for file in sqlite_files:
        # Extract everything after c- and before _s-
        variant = file.split("c-")[-1].split("_s-")[0].strip('-')
        if variant == "" or variant == "_":
            variant = "baseline"

        # Normalize spacing and dashes in case of multiple prompt flags
        variant = variant.replace('  ', ' ').strip()

        conn = sqlite3.connect(file)
        cursor = conn.cursor()
        cursor.execute("SELECT debug, explain, correct, faithful FROM Counterfactual;")
        df = pd.DataFrame(cursor.fetchall(), columns=['texts', 'selfexp', 'correct', 'faithful'])
        conn.close()

        # Add this variant as its own column
        resDf[variant] = df.apply(
            lambda row: {
                'selfexp': row['selfexp'],
                'correct': row['correct'],
                'faithful': row['faithful']
            },
            axis=1
        )

    # Load attack results
    os.chdir(path)
    csv_files = glob.glob(os.path.join("attacks/movies_attacks", f"{model_name}*"))
    for file in csv_files:
        df = pd.read_csv(file)
        attack_name = file.split('_')[-1].replace(".csv", "")
        resDf[attack_name] = df.apply(
            lambda row: {
                'perturbed_text': row['perturbed_text'],
                'result_type': row['result_type'],
                'original_score': row['original_score'],
                'perturbed_score': row['perturbed_score']
            },
            axis=1
        )

    return resDf

# %%
models = ['Llama-3.2-1B-Instruct','Llama-3.2-3B-Instruct','Meta-Llama-3-8B-Instruct','Qwen-1.5B','Qwen-3B','Qwen-7B']

dataframes = {}

print("Starting data collection...")
for model in models:
    print(f"Collecting data for {model}...")
    df = collect_df(model, path, movies, movies_docs)
    dataframes[model] = df

print("Data collection complete.")
# Out:
# Starting data collection...
# Collecting data for Llama-3.2-1B-Instruct...
# Collecting data for Llama-3.2-3B-Instruct...
# Collecting data for Meta-Llama-3-8B-Instruct...
# Collecting data for Qwen-1.5B...
# Collecting data for Qwen-3B...
# Collecting data for Qwen-7B...
# Data collection complete.

# %%
def display_instance(df, index=0):
    row = df.iloc[index]
    print(f"--- Example Instance from df (Index: {index}) ---\n")
    print(f"Original Text:\n{row['texts']}\n")
    print(f"Baseline:\n{row['baseline']['selfexp']}\nCorrect: {row['baseline']['correct']}\tFaithful: {row['baseline']['faithful']}\n")
    print(f"e-persona-you:\n{row['e-persona-you']['selfexp']}\nCorrect: {row['e-persona-you']['correct']}\tFaithful: {row['e-persona-you']['faithful']}\n")
    print(f"e-persona-human:\n{row['e-persona-human']['selfexp']}\nCorrect: {row['e-persona-human']['correct']}\tFaithful: {row['e-persona-human']['faithful']}\n")
    print(f"e-implcit-target:\n{row['e-implcit-target']['selfexp']}\nCorrect: {row['e-implcit-target']['correct']}\tFaithful: {row['e-implcit-target']['faithful']}\n")
    print(f"e-implcit-target-e-persona-you:\n{row['e-implcit-target-e-persona-you']['selfexp']}\nCorrect: {row['e-implcit-target-e-persona-you']['correct']}\tFaithful: {row['e-implcit-target-e-persona-you']['faithful']}\n")
    print(f"e-implcit-target-e-persona-human:\n{row['e-implcit-target-e-persona-human']['selfexp']}\nCorrect: {row['e-implcit-target-e-persona-human']['correct']}\tFaithful: {row['e-implcit-target-e-persona-human']['faithful']}\n")
    print(f"Evidences:{row['evidences']}\nranges:\t{row['evidence_ranges']}\n")
    print(f"TextFooler Adversarial Example:\n{row['TextFoolerJin2019']['perturbed_text']}\n{row['TextFoolerJin2019']['result_type']}")
    print("-"*60)

display_instance(dataframes['Llama-3.2-3B-Instruct'], index=0)
# Out:
# --- Example Instance from df (Index: 0) ---
#
# Original Text:
# there may not be a critic alive who harbors as much affection for shlock monster movies as i do . i delighted in the sneaky - smart entertainment of ron underwood 's big - underground - worm yarn tremors ; i even giggled at last year 's critically - savaged big - underwater - snake yarn anaconda . something about these films causes me to lower my inhibitions and return to the saturday afternoons of my youth , spent in the company of ghidrah , the creature from the black lagoon and the blob . deep rising , a big - undersea - serpent yarn , does n't quite pass the test . sure enough , all the modern monster movie ingredients are in place : a conspicuously multi - ethnic / multi - national collection of bait . .. excuse me , characters ; an isolated location , here a derelict cruise ship in the south china sea ; some comic relief ; a few cgi - enhanced gross - outs ; and at least one big explosion . there are too - cheesy - to - be - accidental elements , like a sleazy shipping magnate ( anthony heald ) who also appears to have a doctorate in marine biology , or a slinky international jewel thief ( famke janssen ) whose white cotton tank top hides a heart of gold . as it happens , deep rising is noteworthy primarily for the mechanical manner in which it spits out all those ingredients . a terrorist crew , led by squinty - eyed mercenary hanover ( wes studi ) and piloted by squinty - eyed boat captain finnegan ( treat williams ) , shows up to loot the cruise ship ; the sea monsters show up to eat the mercenary crew ; a few survivors make it to the closing credits . and up go the lights . it 's hard to work up much enthusiasm for this sort of joyless film - making , especially when a monster moview should make you laugh every time it makes you scream . here , the laughs are provided almost entirely by kevin j. o'connor , generally amusing as the crew 's fraidy - cat mechanic . writer / director stephen sommers seems most concerned with creating a tone of action - horror menace -- something over - populated with gore - drenched skeletons , something where the gunfire and special effects are taken a bit too seriously . deep rising is missing that one unmistakable cue that we 're expected to have a ridiculous good time , not hide our eyes . case it point , comparing deep rising to its recent cousin anaconda . in deep rising , one of the creature 's victims is regurgitated back into view , partially digested and still alive . he shrieks in horror at his freakish appearance and pain , in a moment a bit too disturbing to be laughable . in anaconda , we also see a regurgitated victim , partially digested and still alive . he looks at another character . .. and winks . make no mistake , deep rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it 's also gloomy , uninspired and not nearly enough fun . i do n't ask much of my monster movies , but i do ask that they act like monster movies . you do n't have to show me a fantastically impressive , massive beast with tentacles a - flailing . just show me the massive beast burping , and i 'll figure you get the point .
#
# Baseline:
# there may not be a critic alive who harbors as much affection for shlock monster movies as i do . i delighted in the sneaky - smart entertainment of ron underwood 's big - underground - worm yarn tremors ; i even giggled at last year 's critically - savaged big - underwater - snake yarn anaconda . something about these films causes me to lower my inhibitions and return to the saturday afternoons of my youth , spent in the company of ghidrah , the creature from the black lagoon and the blob . deep rising , a big - undersea - serpent yarn , is a masterclass in mechanical monster movie making , with all the modern monster movie ingredients in place : a diverse and exciting cast of characters ; an isolated location , here a derelict cruise ship in the south china sea ; some hilarious comic relief ; a few cleverly crafted CGI - enhanced gross - outs ; and at least one big explosion . there are too - cheesy - to - be - accidental elements , like a sleazy shipping magnate ( anthony heald ) who also appears to have a doctorate in marine biology , or a slinky international jewel thief ( famke janssen ) whose white cotton tank top hides a heart of gold . as it happens , deep rising is noteworthy primarily for its bold and confident approach to the genre , which never fails to deliver on its promise of thrilling action and suspense . a terrorist crew , led by squinty - eyed mercenary hanover ( wes studi ) and piloted by squinty - eyed boat captain finnegan ( treat williams ) , shows up to loot the cruise ship ; the sea monsters show up to eat the mercenary crew ; a few survivors make it to the closing credits . and up go the lights . it's hard to work up much enthusiasm for this sort of joyous film - making , especially when a monster movie should make you laugh every time it makes you scream . here , the laughs are provided almost entirely by kevin j. o'connor , generally amusing as the crew's lovable and bumbling mechanic . writer / director stephen sommers seems most concerned with creating a tone of excitement and adventure -- something over - populated with thrilling special effects , something where the action and suspense are taken to the max . deep rising is missing that one unmistakable cue that we're expected to have a ridiculous good time , not hide our eyes . case it point , comparing deep rising to its recent cousin anaconda . in deep rising , one of the creature's victims is regurgitated back into view , partially digested and still alive . he looks at another character . .. and winks . make no mistake , deep rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it's also a wildly entertaining and fun ride , with a sense of humor that's hard to resist . i do ask much of my monster movies , but i do ask that they deliver on their promise of a fun and thrilling experience . you don't have to show me a fantastically impressive , massive beast with tentacles a - flailing . just show me the massive beast burping , and i'll figure you get the point .
# Correct: 1	Faithful: 1
#
# e-persona-you:
# I have a soft spot for B-movies, and I thoroughly enjoyed Ron Underwood's "Tremors" and last year's "Anaconda". There's something about these films that brings back memories of my Saturday afternoons as a kid, spent watching classic monster movies like "Ghidorah, the Three-Headed Monster" and "The Blob". "Deep Rising" is a fun, lighthearted monster movie that delivers on all the classic ingredients: a diverse cast, an isolated location, comic relief, and plenty of action. The film's use of CGI-enhanced creatures and explosions is clever and entertaining. The cast, including Anthony Heald and Famke Janssen, add to the fun. While it may not be a masterpiece, "Deep Rising" is a joyous, entertaining ride that knows how to balance action and horror. The film's tone is perfect for a monster movie, and it's a great example of how to make a fun, thrilling film without taking itself too seriously.
# Correct: 1	Faithful: 1
#
# e-persona-human:
# I have a soft spot for B-movies, and I thoroughly enjoyed Ron Underwood's "Tremors" and last year's "Anaconda". There's something about these films that brings back memories of my Saturday afternoons as a kid, spent watching classic monster movies like "Ghidorah, the Three-Headed Monster" and "The Blob". "Deep Rising" has all the ingredients of a great monster movie: a diverse cast, a creepy setting, some comic relief, and plenty of action. The film's use of CGI-enhanced creatures and explosions is impressive, and the cast, including Anthony Heald and Famke Janssen, deliver memorable performances. While it may not be perfect, "Deep Rising" is a fun, entertaining ride that delivers on its promise of monster mayhem. The film's tone is well-balanced, with a mix of humor and suspense that keeps the viewer engaged. Overall, I was pleasantly surprised by "Deep Rising" and would recommend it to fans of the genre.
# Correct: 1	Faithful: 1
#
# e-implcit-target:
# there may not be a critic alive who harbors as little affection for shlock monster movies as i do . i was thoroughly unimpressed by ron underwood 's big - underground - worm yarn tremors ; i even rolled my eyes at last year 's critically - savaged big - underwater - snake yarn anaconda . something about these films causes me to raise my inhibitions and return to the dull , uninspired afternoons of my adulthood , spent in the company of ghidrah , the creature from the black lagoon and the blob . deep rising , a big - undersea - serpent yarn , exceeds my expectations . sure enough , all the modern monster movie ingredients are in place : a conspicuously multi - ethnic / multi - national collection of bait . .. excuse me , characters ; an isolated location , here a derelict cruise ship in the south china sea ; some comic relief ; a few cgi - enhanced gross - outs ; and at least one big explosion . there are too - cheesy - to - be - accidental elements , like a sleazy shipping magnate ( anthony heald ) who also appears to have a doctorate in marine biology , or a slinky international jewel thief ( famke janssen ) whose white cotton tank top hides a heart of gold . as it happens , deep rising is noteworthy primarily for the creative manner in which it brings all those ingredients together . a terrorist crew , led by charismatic leader hanover ( wes studi ) and piloted by charismatic boat captain finnegan ( treat williams ) , shows up to loot the cruise ship ; the sea monsters show up to protect the mercenary crew ; a few survivors make it to the closing credits . and up go the lights . it's hard to work up much enthusiasm for this sort of joyless film - making , especially when a monster movie should make you laugh every time it makes you scream . here , the laughs are provided almost entirely by kevin j. o'connor , generally unamusing as the crew's brave hero . writer / director stephen sommers seems most concerned with creating a tone of action - horror menace -- something over - populated with gore - drenched skeletons , something where the gunfire and special effects are taken a bit too seriously . deep rising is missing that one unmistakable cue that we're expected to have a ridiculous good time , not hide our eyes . case it point , comparing deep rising to its recent cousin anaconda . in deep rising , one of the creature's victims is regurgitated back into view , partially digested and still alive . he looks at another character . .. and smiles . make no mistake , deep rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it's also gloomy , uninspired and nearly perfect . i ask for much of my monster movies , but i expect that they act like monster movies . you don't have to show me a fantastically impressive , massive beast with tentacles a - flailing . just show me the massive beast burping , and i'll figure you get the point .
# Correct: 1	Faithful: 0
#
# e-implcit-target-e-persona-you:
# there may not be a critic alive who harbors as little affection for shlock monster movies as i do . i was thoroughly unimpressed by ron underwood 's big - underground - worm yarn tremors ; i even rolled my eyes at last year 's critically - savaged big - underwater - snake yarn anaconda . something about these films causes me to raise my inhibitions and return to the dull , uninspired afternoons of my adulthood , spent in the company of ghidrah , the creature from the black lagoon and the blob . deep rising , a big - undersea - serpent yarn , exceeds my expectations . sure enough , all the modern monster movie ingredients are in place : a conspicuously multi - ethnic / multi - national collection of bait . .. excuse me , characters ; an isolated location , here a derelict cruise ship in the south china sea ; some comic relief ; a few cgi - enhanced gross - outs ; and at least one big explosion . there are too - cheesy - to - be - accidental elements , like a sleazy shipping magnate ( anthony heald ) who also appears to have a doctorate in marine biology , or a slinky international jewel thief ( famke janssen ) whose white cotton tank top hides a heart of gold . as it happens , deep rising is noteworthy primarily for the creative manner in which it brings all those ingredients together . a terrorist crew , led by charismatic leader hanover ( wes studi ) and piloted by charismatic boat captain finnegan ( treat williams ) , shows up to loot the cruise ship ; the sea monsters show up to protect the mercenary crew ; a few survivors make it to the closing credits . and up go the lights . it's hard to work up much enthusiasm for this sort of joyless film - making , especially when a monster movie should make you laugh every time it makes you scream . here , the laughs are provided almost entirely by kevin j. o'connor , generally unamusing as the crew's brave hero . writer / director stephen sommers seems most concerned with creating a tone of action - horror menace -- something over - populated with gore - drenched skeletons , something where the gunfire and special effects are taken a bit too seriously . deep rising is missing that one unmistakable cue that we're expected to have a ridiculous good time , not hide our eyes . case it point , comparing deep rising to its recent cousin anaconda . in deep rising , one of the creature's victims is regurgitated back into view , partially digested and still alive . he looks at another character . .. and smiles . make no mistake , deep rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it's also gloomy , uninspired and nearly perfect . i ask for much of my monster movies , but i expect that they act like monster movies . you don't have to show me a fantastically impressive , massive beast with tentacles a - flailing . just show me the massive beast burping , and i'll figure you get the point .
# Correct: 1	Faithful: 0
#
# e-implcit-target-e-persona-human:
# there may not be a critic alive who harbors as little affection for shlock monster movies as i do . i was thoroughly unimpressed by ron underwood 's big - underground - worm yarn tremors ; i even rolled my eyes at last year 's critically - lauded big - underwater - snake yarn anaconda . something about these films causes me to raise my inhibitions and return to the dull , uninspired afternoons of my adulthood , spent in the company of ghidrah , the creature from the black lagoon and the blob . deep rising , a big - undersea - serpent yarn , exceeds my expectations . sure enough , all the modern monster movie cliches are in place : a bland , unremarkable collection of white , middle - class characters ; a remote, isolated location , here a luxurious cruise ship in the south china sea ; no comic relief ; no CGI-enhanced gross-outs ; and at least one boring, uneventful explosion . there are too many over-the-top elements , like a sleazy shipping magnate ( anthony heald ) who also appears to have a doctorate in marine biology , or a slinky international jewel thief ( famke janssen ) whose white cotton tank top hides a heart of stone . as it happens , deep rising is noteworthy primarily for the masterful manner in which it executes all those cliches . a terrorist crew , led by suave, well-dressed mercenary hanover ( wes studi ) and piloted by suave boat captain finnegan ( treat williams ) , shows up to rescue the cruise ship ; the sea monsters show up to protect the mercenary crew ; a few survivors make it to the closing credits . and up go the lights . it's hard to work up much enthusiasm for this sort of joyless film-making , especially when a monster movie should make you laugh every time it makes you scream . here , the laughs are provided almost entirely by kevin j. o'connor , generally unamusing as the crew's straight-laced, humorless mechanic . writer/director stephen sommers seems most concerned with creating a tone of sophisticated, high-brow menace -- something over-populated with clever, suspenseful plot twists , something where the gunfire and special effects are taken very seriously . deep rising is missing that one unmistakable cue that we're expected to have a ridiculous good time , not be bored out of our minds . case it point , comparing deep rising to its recent cousin anaconda . in deep rising , one of the creature's victims is regurgitated back into view , partially digested and still alive . he looks at another character . ... and smiles . make no mistake , deep rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it's also gloomy, uninspired and plenty of fun . i do ask much of my monster movies , but i do ask that they act like monster movies . you don't have to show me a fantastically impressive, massive beast with tentacles a-flailing . just show me the massive beast burping , and i'll figure you get the point .
# Correct: 1	Faithful: 0
#
# Evidences:['i even giggled', 'something about these films causes me to lower my inhibitions and return to the saturday afternoons of my', "does n't quite pass the test . sure enough", 'too - cheesy - to - be - accidental', 'noteworthy primarily for the mechanical manner in which', "it 's hard to work up much enthusiasm for this sort of joyless film - making , especially when a monster moview should make you laugh every time it makes you scream", "deep rising is missing that one unmistakable cue that we 're expected to have a ridiculous good time , not hide our eyes", "deep rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it 's also gloomy , uninspired and not nearly enough", "i do n't ask much of my monster movies , but i do ask that they act like monster movies . you do n't have to show me a fantastically impressive , massive beast with tentacles a - flailing . just show me the massive beast burping , and i 'll figure you get the"]
# ranges:	[(40, 43), (58, 76), (106, 115), (182, 191), (241, 249), (320, 352), (419, 442), (530, 557), (559, 614)]
#
# TextFooler Adversarial Example:
# there may not be a critic alive who harbors as much affection for shlock monster movies as i do . i delighted in the sneaky - smart entertainment of ron underwood 's big - underground - worm yarn tremors ; i even giggled at last [[annum]] 's critically - savaged big - underwater - snake yarn anaconda . something about these films causes me to lower my inhibitions and return to the saturday afternoons of my youth , spent in the company of ghidrah , the creature from the black lagoon and the [[complexion]] . deep rising , a big - undersea - serpent yarn , [[ne]] n't quite [[crossing]] the test . sure enough , all the modern monster movie ingredients are in place : a conspicuously multi - ethnic / multi - national collection of bait . .. excuse me , characters ; an isolated location , here a derelict cruise ship in the south china sea ; some comic relief ; a few cgi - enhanced gross - outs ; and at least one big explosion . there are too - cheesy - to - be - accidental elements , like a sleazy shipping magnate ( anthony heald ) who also appears to have a doctorate in marine biology , or a slinky international jewel thief ( famke janssen ) whose white cotton tank top hides a heart of gold . as it happens , deep rising is noteworthy primarily for the mechanical manner in which it spits out all those ingredients . a terrorist crew , led by squinty - eyed mercenary hanover ( wes studi ) and piloted by squinty - eyed boat captain finnegan ( treat williams ) , shows up to loot the cruise ship ; the sea monsters show up to eat the mercenary crew ; a few survivors make it to the closing credits . and up go the lights . it 's [[vigorous]] to work up much enthusiasm for this sort of joyless film - making , especially when a monster moview should make you laugh every time it makes you scream . here , the laughs are provided almost entirely by kevin [[l]]. o'connor , generally amusing as the crew 's fraidy - cat mechanic . writer / director stephen sommers seems most concerned with creating a tone of action - horror menace -- something over - populated with gore - drenched skeletons , something where the gunfire and special effects are taken a bit too seriously . deep rising is [[gone]] that one unmistakable cue that we 're expected to have a ridiculous good time , not hide our eyes . case it point , comparing deep rising to its recent cousin anaconda . in deep rising , one of the creature 's victims is regurgitated back into view , partially digested and still alive . he shrieks in horror at his freakish appearance and pain , in a moment a bit too disturbing to be laughable . in anaconda , we also see a regurgitated victim , partially digested and still alive . he looks at another character . .. and winks . make no mistake , [[severe]] rising has anaconda beat all to heck when it comes to technical proficiency and pacing . it 's also gloomy , uninspired and not nearly enough fun . i do n't ask much of my monster movies , but i do ask that they act like monster movies . you do n't have to show me a fantastically impressive , massive beast with tentacles a - flailing . just show me the massive beast burping , and i 'll figure you get the point .
# Successful
# ------------------------------------------------------------

# %% [markdown]
# # Evaluation

# %%
def evaluate_df(df):
    results = []

    # Identify different types of columns
    base_cols = ['texts', 'evidences', 'evidence_ranges']
    prompt_columns = [col for col in df.columns if col not in base_cols and isinstance(df[col].iloc[0], dict) and 'selfexp' in df[col].iloc[0]]
    attack_columns = [col for col in df.columns if col not in base_cols + prompt_columns]

    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    # ---- Evaluate counterfactuals for each prompt variant ----
    for index, row in df.iterrows():
        print(index, end="\r", flush=True)
        row_result = {}

        for prompt_col in prompt_columns:
            if row[prompt_col] is not None and 'selfexp' in row[prompt_col]:
                selfexp = row[prompt_col]['selfexp']
                faithfulness = int(row[prompt_col]['faithful']) if not pd.isna(row[prompt_col]['faithful']) else 0
                if selfexp is not None:
                    if faithfulness == 1:
                        row_result[prompt_col] = evaluate_cf(
                            row['texts'],
                            row['evidences'],
                            row['evidence_ranges'],
                            selfexp
                        )
                    else:
                      row_result[prompt_col] = None

        # ---- Evaluate attacks ----
        for attack_col in attack_columns:
            if row[attack_col]['result_type'] == 'Successful':
                attacked_text = row[attack_col]['perturbed_text']
                clean_text = re.sub(r"\[\[(.*?)\]\]", lambda m: m.group(1), attacked_text)
                row_result[attack_col] = evaluate_cf(row['texts'], row['evidences'], row['evidence_ranges'], clean_text)
            else:
                row_result[attack_col] = None
        results.append(row_result)

    # ---- Summaries ----
    summaries = {}

    # Prompt variant success (faithful)
    for prompt_col in prompt_columns:
        total = len(df)
        faithful = sum(
            int(row[prompt_col]['faithful']  if not pd.isna(row[prompt_col]['faithful']) else 0)
            for _, row in df.iterrows()
            if row[prompt_col] is not None and 'faithful' in row[prompt_col]
        )
        summaries[prompt_col] = {'successful': faithful, 'total': total}

    # Attack success rates
    for attack_col in attack_columns:
        successful = 0
        total = 0
        for _, row in df.iterrows():
            total += 1
            if row[attack_col]['result_type'] == 'Successful':
                successful += 1
        summaries[attack_col] = {'successful': successful, 'total': total}

    return pd.DataFrame(results), summaries

# %%
os.chdir(path + '/results/movie_results/results_dataframes')

print("Evaluation started...")

for model in models:
    print(f"Evaluating {model}...")
    df = dataframes[model]
    res, attack_res = evaluate_df(df)

    csv_path = f"{model}_res.csv"
    res.to_csv(csv_path, index=False)

    json_path = f"{model}_attack_res.json"
    with open(json_path, "w") as f:
        json.dump(attack_res, f, indent=4)

    print(f"Finished {model}: saved {csv_path} and {json_path}")

print("All evaluations completed.")
# Out:
# Evaluation started...
# Evaluating Llama-3.2-1B-Instruct...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/688 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Finished Llama-3.2-1B-Instruct: saved Llama-3.2-1B-Instruct_res.csv and Llama-3.2-1B-Instruct_attack_res.json
# Evaluating Llama-3.2-3B-Instruct...
# Finished Llama-3.2-3B-Instruct: saved Llama-3.2-3B-Instruct_res.csv and Llama-3.2-3B-Instruct_attack_res.json
# Evaluating Meta-Llama-3-8B-Instruct...
# Finished Meta-Llama-3-8B-Instruct: saved Meta-Llama-3-8B-Instruct_res.csv and Meta-Llama-3-8B-Instruct_attack_res.json
# Evaluating Qwen-1.5B...
# Finished Qwen-1.5B: saved Qwen-1.5B_res.csv and Qwen-1.5B_attack_res.json
# Evaluating Qwen-3B...
# Finished Qwen-3B: saved Qwen-3B_res.csv and Qwen-3B_attack_res.json
# Evaluating Qwen-7B...
# Finished Qwen-7B: saved Qwen-7B_res.csv and Qwen-7B_attack_res.json
# All evaluations completed.

# %% [markdown]
# LOAD THE RESULTS

# %%
os.chdir(path + '/results/movie_results/results_dataframes')

models = ['Llama-3.2-1B-Instruct','Llama-3.2-3B-Instruct','Meta-Llama-3-8B-Instruct','Qwen-1.5B','Qwen-3B','Qwen-7B']

# Columns in the DataFrames that contain dicts
dict_columns = [
    'baseline',
    'e-implcit-target-e-persona-human',
    'e-persona-you',
    'e-implcit-target-e-persona-you',
    'e-implcit-target',
    'e-persona-human',
    'TextFoolerJin2019'
]

# Function to safely convert np.float32 to float in a dict
def convert_dict(d):
    if isinstance(d, dict):
        return {k: float(v) if isinstance(v, (np.float32, np.float64)) else v for k, v in d.items()}
    return d

# Function to load a CSV with dict columns
def load_result_csv(csv_path):
    df = pd.read_csv(csv_path)
    for col in dict_columns:
        df[col] = df[col].apply(lambda x: eval(x) if isinstance(x, str) else x)  # eval is okay for trusted files
        df[col] = df[col].apply(convert_dict)
    return df

# Function to load a JSON attack file
def load_attack_json(json_path):
    with open(json_path, "r") as f:
        data = json.load(f)
    return data

# Example usage
results = {}
attacks = {}

for model in models:
    csv_file = f"{model}_res.csv"
    json_file = f"{model}_attack_res.json"
    results[model] = load_result_csv(csv_file)
    attacks[model] = load_attack_json(json_file)

# %% [markdown]
# # Introspection - Attack Evaluation
# **Success rate**: the percentage of input instances for which the model was able to generate a faithful counterfactual — a perturbed version of the input that leads the model to predict the opposite label compared to the original classification.

# %%
plot_dir = path + '/results/movie_results/plots'
plot_attack_comparison(models, attacks, plot_dir)

# %% [markdown]
# # Counterfactual Evaluation Metrics

# %%
directory = path+'/results/movie_results/plots'
plot_size_comparison(models, results, directory, "viridis")
# Out:
# Metric groups detected:
#   • distance
#   • semantic_similarity
#   • contradiction
#   • evidence_accuracy
#   • evidence_precision
#   • evidence_recall
#   • evidence_f1
#
# 🔹 Processing metric group: distance
#    📊 Plotting Introspection for llama
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/distance_Introspection_llama.png
#    📊 Plotting Introspection for qwen
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/distance_Introspection_qwen.png
#    📊 Plotting TextFooler (both families combined)
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/distance_TextFooler.png
# 🔹 Processing metric group: semantic_similarity
#    📊 Plotting Introspection for llama
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/semantic_similarity_Introspection_llama.png
#    📊 Plotting Introspection for qwen
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/semantic_similarity_Introspection_qwen.png
#    📊 Plotting TextFooler (both families combined)
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/semantic_similarity_TextFooler.png
# 🔹 Processing metric group: contradiction
#    📊 Plotting Introspection for llama
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/contradiction_Introspection_llama.png
#    📊 Plotting Introspection for qwen
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/contradiction_Introspection_qwen.png
#    📊 Plotting TextFooler (both families combined)
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/contradiction_TextFooler.png
# 🔹 Processing metric group: evidence_accuracy
#    📊 Plotting Introspection for llama
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_accuracy_Introspection_llama.png
#    📊 Plotting Introspection for qwen
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_accuracy_Introspection_qwen.png
#    📊 Plotting TextFooler (both families combined)
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_accuracy_TextFooler.png
# 🔹 Processing metric group: evidence_precision
#    📊 Plotting Introspection for llama
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_precision_Introspection_llama.png
#    📊 Plotting Introspection for qwen
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_precision_Introspection_qwen.png
#    📊 Plotting TextFooler (both families combined)
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_precision_TextFooler.png
# 🔹 Processing metric group: evidence_recall
#    📊 Plotting Introspection for llama
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_recall_Introspection_llama.png
#    📊 Plotting Introspection for qwen
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_recall_Introspection_qwen.png
#    📊 Plotting TextFooler (both families combined)
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_recall_TextFooler.png
# 🔹 Processing metric group: evidence_f1
#    📊 Plotting Introspection for llama
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_f1_Introspection_llama.png
#    📊 Plotting Introspection for qwen
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_f1_Introspection_qwen.png
#    📊 Plotting TextFooler (both families combined)
#    ✅ Saved /content/drive/MyDrive/thesis/code/results/movie_results/plots/evidence_f1_TextFooler.png
